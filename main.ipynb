# %%
from collections import defaultdict
import cv2
import numpy as np
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO(r"Training\runs\detect\train\weights\best.pt")
video_path = r"toll_gate.mp4"
output_path = r"vehicle_count_output.mp4"

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# Create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# Store the track history
track_history = defaultdict(lambda: [])

## Get video frame rate
# fps = cap.get(cv2.CAP_PROP_FPS)
wait_time = int(1000 / fps)  # Waktu tunggu dalam milidetik antara setiap frame

# Koordinat untuk menggambar garis
coordinates = {
    "points": [
        ((0, 125), (0, 135)),
        ((75, 165), (75, 175)),
        ((140, 180), (140, 190)),
        ((205, 193), (205, 203)),
        ((273, 208), (273, 218)),
        ((340, 222), (340, 232)),
        ((410, 238), (410, 248)),
        ((484, 255), (484, 265)),
        ((562, 273), (562, 283))
    ],
    "gates": [
        ((0, 125), (65, 150)),
        ((65, 150), (140, 180)),
        ((140, 180), (205, 193)),
        ((205, 193), (273, 208)),
        ((273, 208), (340, 222)),
        ((340, 222), (410, 238)),
        ((410, 238), (484, 255)),
        ((484, 255), (562, 273))
    ]
}

# Struktur data untuk menghitung kendaraan
vehicle_counts = [{"BUS": 0, "CAR": 0} for _ in range(8)]
counted_vehicles = set()

def point_in_polygon(x, y, poly):
    n = len(poly)
    inside = False
    p1x, p1y = poly[0]
    for i in range(n + 1):
        p2x, p2y = poly[i % n]
        if y > min(p1y, p2y):
            if y <= max(p1y, p2y):
                if x <= max(p1x, p2x):
                    if p1y != p2y:
                        xinters = (y - p1y) * (p2x - p1x) / (p2y - p1y) + p1x
                    if p1x == p2x or x <= xinters:
                        inside = not inside
        p1x, p1y = p2x, p2y
    return inside

# Loop through the video frames
frame_count = 0
while cap.isOpened():
    # Break the loop if 'q' is pressed
    if cv2.waitKey(wait_time) & 0xFF == ord("q"):
        break
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Get the boxes and track IDs
        boxes = results[0].boxes.xywh.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        classes = results[0].boxes.cls.cpu().tolist()

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Plot the tracks and count vehicles
        for box, track_id, cls in zip(boxes, track_ids, classes):
            x, y, w, h = box
            track = track_history[track_id]
            track.append((float(x), float(y)))  # x, y center point
            if len(track) > 100:
                track.pop(0)

            # Draw the tracking lines
            points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
            cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=5)

            # Check if vehicle crossed any gate
            for i, (gateA, gateB) in enumerate(coordinates["gates"]):
                gate_poly = [gateA, gateB, (gateB[0], gateB[1]+10), (gateA[0], gateA[1]+10)]
                if point_in_polygon(x, y, gate_poly) and (track_id, i) not in counted_vehicles:
                    vehicle_class = "BUS" if cls == 0 else "CAR"
                    vehicle_counts[i][vehicle_class] += 1
                    counted_vehicles.add((track_id, i))

        # Draw lines on annotated frames
        for pointA, pointB in coordinates["points"]:
            cv2.line(annotated_frame, pointA, pointB, color=(0, 0, 255), thickness=4)

        # Draw gates and add names on them
        for i, (gateA, gateB) in enumerate(coordinates["gates"]):
            cv2.line(annotated_frame, gateA, gateB, color=(0, 255, 0), thickness=4)
    
            # Defines the text position for the gate name.
            text_position = ((gateA[0] + gateB[0]) // 2, (gateA[1] + gateB[1]) // 2 - 10)
    
            # Add gate name text above the line
            gate_name = f"Gate {i+1}"
            cv2.putText(annotated_frame, gate_name, text_position, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)

        # Display vehicle counts
        # Display vehicle counts for gates 1-4 on the left side
        for i in range(4):
            text = f"Gate {i+1}: BUS {vehicle_counts[i]['BUS']}, CAR {vehicle_counts[i]['CAR']}"
            cv2.putText(annotated_frame, text, (10, 30 + i*20), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (191, 0, 255), 2)

        # Display vehicle counts for gates 5-8 on the right side
        for i in range(4, 8):
            text = f"Gate {i+1}: BUS {vehicle_counts[i]['BUS']}, CAR {vehicle_counts[i]['CAR']}"
            text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2)[0]
            text_x = annotated_frame.shape[1] - text_size[0] - 10
            cv2.putText(annotated_frame, text, (text_x, 30 + (i-4)*20), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (191, 0, 255), 2)

        # Add text at the bottom center
        total_bus = sum(count["BUS"] for count in vehicle_counts)
        total_car = sum(count["CAR"] for count in vehicle_counts)
        total_vehicles = total_bus + total_car

        # Menambahkan tulisan di bagian bawah tengah
        text_bottom = f"BUS = {total_bus} || CAR = {total_car} || TOTAL = {total_vehicles}"
        text_size = cv2.getTextSize(text_bottom, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)[0]
        text_x = (annotated_frame.shape[1] - text_size[0]) // 2
        text_y = annotated_frame.shape[0] - 10

        # Draw text on annotated frames
        cv2.putText(annotated_frame, text_bottom, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2)

        # # Display progress
        # frame_count += 1
        # progress = f"Progress: {frame_count}/{total_frames} frames"
        # cv2.putText(annotated_frame, progress, (10, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Write the frame to the output video
        out.write(annotated_frame)

    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
out.release()
cv2.destroyAllWindows()

print()
print(f"Video processing completed. Output saved to: {output_path}")

# Print result after video complete
print()
print("Vehicle Detection Results per Gate:")
for i in range(8):
    gate_result = f"Gate {i+1}: BUS {vehicle_counts[i]['BUS']}, CAR {vehicle_counts[i]['CAR']}"
    print(gate_result)

# Print total of transportation
total_bus = sum(count["BUS"] for count in vehicle_counts)
total_car = sum(count["CAR"] for count in vehicle_counts)
total_vehicles = total_bus + total_car
print(f"\nTotal:")
print(f"BUS = {total_bus}, CAR = {total_car}, TOTAL = {total_vehicles}")
# Out:
# 0: 384x640 1 BUS, 1 CAR, 100.7ms
# Speed: 0.0ms preprocess, 100.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 64.9ms
# Speed: 1.1ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 65.7ms
# Speed: 0.0ms preprocess, 65.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 49.2ms
# Speed: 1.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 54.3ms
# Speed: 0.0ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 55.6ms
# Speed: 1.3ms preprocess, 55.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 58.4ms
# Speed: 0.8ms preprocess, 58.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 49.3ms
# Speed: 0.8ms preprocess, 49.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 58.3ms
# Speed: 1.4ms preprocess, 58.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 74.0ms
# Speed: 0.7ms preprocess, 74.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 49.1ms
# Speed: 1.4ms preprocess, 49.1ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 58.9ms
# Speed: 0.0ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 60.4ms
# Speed: 1.2ms preprocess, 60.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 58.7ms
# Speed: 1.4ms preprocess, 58.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 58.8ms
# Speed: 2.3ms preprocess, 58.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 50.9ms
# Speed: 0.0ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 60.5ms
# Speed: 0.8ms preprocess, 60.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 50.2ms
# Speed: 0.3ms preprocess, 50.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 53.6ms
# Speed: 2.0ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 54.7ms
# Speed: 1.4ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 54.2ms
# Speed: 1.0ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 53.1ms
# Speed: 0.3ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 48.5ms
# Speed: 1.5ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 56.9ms
# Speed: 1.8ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 57.5ms
# Speed: 0.0ms preprocess, 57.5ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 54.8ms
# Speed: 0.3ms preprocess, 54.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 54.7ms
# Speed: 0.3ms preprocess, 54.7ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 48.0ms
# Speed: 2.1ms preprocess, 48.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 53.4ms
# Speed: 0.0ms preprocess, 53.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 52.7ms
# Speed: 2.1ms preprocess, 52.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 60.6ms
# Speed: 1.2ms preprocess, 60.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 49.7ms
# Speed: 1.4ms preprocess, 49.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 50.7ms
# Speed: 0.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 50.1ms
# Speed: 0.0ms preprocess, 50.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 52.4ms
# Speed: 0.5ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 59.1ms
# Speed: 2.4ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 61.4ms
# Speed: 0.7ms preprocess, 61.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 60.5ms
# Speed: 1.4ms preprocess, 60.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 54.2ms
# Speed: 0.0ms preprocess, 54.2ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 68.7ms
# Speed: 0.0ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 49.3ms
# Speed: 1.6ms preprocess, 49.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 55.6ms
# Speed: 0.0ms preprocess, 55.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 61.9ms
# Speed: 1.2ms preprocess, 61.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 59.0ms
# Speed: 0.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 50.3ms
# Speed: 0.0ms preprocess, 50.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 55.2ms
# Speed: 0.0ms preprocess, 55.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 52.6ms
# Speed: 0.7ms preprocess, 52.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 49.8ms
# Speed: 0.5ms preprocess, 49.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 56.1ms
# Speed: 1.0ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 50.2ms
# Speed: 0.0ms preprocess, 50.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 50.8ms
# Speed: 0.5ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 63.2ms
# Speed: 1.3ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 57.2ms
# Speed: 1.1ms preprocess, 57.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 79.4ms
# Speed: 2.3ms preprocess, 79.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 56.9ms
# Speed: 1.5ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 52.0ms
# Speed: 1.2ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 62.6ms
# Speed: 1.8ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 60.0ms
# Speed: 2.3ms preprocess, 60.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 56.4ms
# Speed: 1.8ms preprocess, 56.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 53.7ms
# Speed: 0.0ms preprocess, 53.7ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 65.3ms
# Speed: 2.0ms preprocess, 65.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 49.1ms
# Speed: 2.0ms preprocess, 49.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 61.1ms
# Speed: 1.0ms preprocess, 61.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 61.3ms
# Speed: 1.1ms preprocess, 61.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 59.3ms
# Speed: 1.0ms preprocess, 59.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 65.6ms
# Speed: 1.9ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 49.7ms
# Speed: 0.8ms preprocess, 49.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 62.5ms
# Speed: 1.3ms preprocess, 62.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 58.4ms
# Speed: 0.9ms preprocess, 58.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 64.5ms
# Speed: 1.5ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 58.7ms
# Speed: 1.1ms preprocess, 58.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 58.2ms
# Speed: 1.1ms preprocess, 58.2ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 57.5ms
# Speed: 0.5ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 50.0ms
# Speed: 0.9ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 59.8ms
# Speed: 0.8ms preprocess, 59.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 50.3ms
# Speed: 1.6ms preprocess, 50.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 61.5ms
# Speed: 1.0ms preprocess, 61.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 53.6ms
# Speed: 1.7ms preprocess, 53.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 74.7ms
# Speed: 2.2ms preprocess, 74.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 63.5ms
# Speed: 0.9ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 53.1ms
# Speed: 1.8ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 65.7ms
# Speed: 0.0ms preprocess, 65.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 65.0ms
# Speed: 2.3ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 50.3ms
# Speed: 1.6ms preprocess, 50.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 56.2ms
# Speed: 0.4ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 57.9ms
# Speed: 1.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 63.4ms
# Speed: 0.8ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 67.1ms
# Speed: 0.8ms preprocess, 67.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 64.1ms
# Speed: 0.8ms preprocess, 64.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 64.1ms
# Speed: 0.5ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 66.4ms
# Speed: 0.9ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 57.2ms
# Speed: 1.3ms preprocess, 57.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 57.2ms
# Speed: 0.0ms preprocess, 57.2ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 57.2ms
# Speed: 1.0ms preprocess, 57.2ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 65.3ms
# Speed: 1.4ms preprocess, 65.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 63.9ms
# Speed: 2.9ms preprocess, 63.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 47.3ms
# Speed: 2.0ms preprocess, 47.3ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 53.0ms
# Speed: 1.8ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 50.6ms
# Speed: 0.0ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 62.5ms
# Speed: 1.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 67.2ms
# Speed: 1.0ms preprocess, 67.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 51.6ms
# Speed: 0.9ms preprocess, 51.6ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 81.7ms
# Speed: 1.9ms preprocess, 81.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 76.2ms
# Speed: 0.9ms preprocess, 76.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 75.7ms
# Speed: 1.0ms preprocess, 75.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 73.9ms
# Speed: 2.1ms preprocess, 73.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 89.4ms
# Speed: 2.6ms preprocess, 89.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 65.7ms
# Speed: 1.0ms preprocess, 65.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 67.2ms
# Speed: 1.6ms preprocess, 67.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 50.1ms
# Speed: 0.8ms preprocess, 50.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 69.4ms
# Speed: 1.5ms preprocess, 69.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 65.9ms
# Speed: 1.1ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 65.5ms
# Speed: 1.4ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 82.9ms
# Speed: 0.5ms preprocess, 82.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 68.6ms
# Speed: 0.7ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 61.3ms
# Speed: 2.3ms preprocess, 61.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 50.1ms
# Speed: 1.6ms preprocess, 50.1ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 66.8ms
# Speed: 1.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 63.2ms
# Speed: 2.5ms preprocess, 63.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 64.7ms
# Speed: 1.4ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 50.0ms
# Speed: 0.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 52.3ms
# Speed: 0.0ms preprocess, 52.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 64.5ms
# Speed: 1.2ms preprocess, 64.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 50.1ms
# Speed: 0.0ms preprocess, 50.1ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 65.2ms
# Speed: 1.0ms preprocess, 65.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 89.4ms
# Speed: 1.5ms preprocess, 89.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 93.1ms
# Speed: 1.3ms preprocess, 93.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 90.2ms
# Speed: 2.3ms preprocess, 90.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 77.9ms
# Speed: 2.0ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 80.7ms
# Speed: 1.2ms preprocess, 80.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 102.6ms
# Speed: 2.3ms preprocess, 102.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 85.7ms
# Speed: 1.7ms preprocess, 85.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 65.1ms
# Speed: 0.9ms preprocess, 65.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 75.6ms
# Speed: 1.9ms preprocess, 75.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 50.3ms
# Speed: 0.0ms preprocess, 50.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 57.7ms
# Speed: 1.1ms preprocess, 57.7ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 65.4ms
# Speed: 2.0ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 72.7ms
# Speed: 0.9ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 74.9ms
# Speed: 2.0ms preprocess, 74.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 79.1ms
# Speed: 0.0ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 69.1ms
# Speed: 2.0ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 71.6ms
# Speed: 0.7ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 66.6ms
# Speed: 1.7ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 69.4ms
# Speed: 0.9ms preprocess, 69.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 62.9ms
# Speed: 2.4ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 65.1ms
# Speed: 0.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 66.8ms
# Speed: 0.8ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 76.1ms
# Speed: 0.0ms preprocess, 76.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 66.8ms
# Speed: 1.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 70.0ms
# Speed: 0.2ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 88.4ms
# Speed: 0.0ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 74.1ms
# Speed: 0.0ms preprocess, 74.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 83.0ms
# Speed: 0.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 59.8ms
# Speed: 2.4ms preprocess, 59.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 70.1ms
# Speed: 1.4ms preprocess, 70.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 69.0ms
# Speed: 0.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 65.7ms
# Speed: 0.0ms preprocess, 65.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 55.2ms
# Speed: 0.0ms preprocess, 55.2ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 69.1ms
# Speed: 0.0ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 80.8ms
# Speed: 1.8ms preprocess, 80.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 67.3ms
# Speed: 0.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 90.4ms
# Speed: 3.0ms preprocess, 90.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 68.6ms
# Speed: 2.0ms preprocess, 68.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 67.3ms
# Speed: 0.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 83.2ms
# Speed: 1.0ms preprocess, 83.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 74.8ms
# Speed: 1.0ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 51.9ms
# Speed: 0.0ms preprocess, 51.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 68.7ms
# Speed: 0.0ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 723.9ms
# Speed: 0.0ms preprocess, 723.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 269.8ms
# Speed: 4.9ms preprocess, 269.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 110.9ms
# Speed: 2.0ms preprocess, 110.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 131.2ms
# Speed: 6.7ms preprocess, 131.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 204.6ms
# Speed: 0.0ms preprocess, 204.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 279.3ms
# Speed: 18.3ms preprocess, 279.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 201.9ms
# Speed: 2.0ms preprocess, 201.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 81.8ms
# Speed: 3.1ms preprocess, 81.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 64.9ms
# Speed: 2.0ms preprocess, 64.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 98.2ms
# Speed: 2.0ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 98.5ms
# Speed: 2.9ms preprocess, 98.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 88.8ms
# Speed: 1.0ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 63.2ms
# Speed: 2.6ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 72.6ms
# Speed: 2.4ms preprocess, 72.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 168.1ms
# Speed: 9.0ms preprocess, 168.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 213.8ms
# Speed: 6.2ms preprocess, 213.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 127.0ms
# Speed: 4.2ms preprocess, 127.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 304.2ms
# Speed: 0.7ms preprocess, 304.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 160.7ms
# Speed: 3.0ms preprocess, 160.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 123.5ms
# Speed: 2.5ms preprocess, 123.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 124.1ms
# Speed: 2.7ms preprocess, 124.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 144.3ms
# Speed: 3.0ms preprocess, 144.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 152.8ms
# Speed: 3.7ms preprocess, 152.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 139.8ms
# Speed: 5.0ms preprocess, 139.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 115.3ms
# Speed: 1.3ms preprocess, 115.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 137.0ms
# Speed: 3.2ms preprocess, 137.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 129.7ms
# Speed: 2.4ms preprocess, 129.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 124.8ms
# Speed: 2.2ms preprocess, 124.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 118.9ms
# Speed: 2.2ms preprocess, 118.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 158.3ms
# Speed: 3.3ms preprocess, 158.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 137.8ms
# Speed: 2.6ms preprocess, 137.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 225.7ms
# Speed: 2.6ms preprocess, 225.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 217.2ms
# Speed: 2.0ms preprocess, 217.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 200.0ms
# Speed: 2.6ms preprocess, 200.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 222.3ms
# Speed: 3.5ms preprocess, 222.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 349.1ms
# Speed: 3.8ms preprocess, 349.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 214.4ms
# Speed: 4.4ms preprocess, 214.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 124.5ms
# Speed: 2.0ms preprocess, 124.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 143.2ms
# Speed: 0.0ms preprocess, 143.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 111.7ms
# Speed: 1.4ms preprocess, 111.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 113.3ms
# Speed: 3.0ms preprocess, 113.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 132.3ms
# Speed: 1.5ms preprocess, 132.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 145.1ms
# Speed: 3.4ms preprocess, 145.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 152.6ms
# Speed: 2.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 132.7ms
# Speed: 4.4ms preprocess, 132.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 124.5ms
# Speed: 4.6ms preprocess, 124.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 138.3ms
# Speed: 5.0ms preprocess, 138.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 190.4ms
# Speed: 0.0ms preprocess, 190.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 95.4ms
# Speed: 1.8ms preprocess, 95.4ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 104.3ms
# Speed: 2.0ms preprocess, 104.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 104.2ms
# Speed: 0.0ms preprocess, 104.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 158.3ms
# Speed: 0.0ms preprocess, 158.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 111.2ms
# Speed: 2.0ms preprocess, 111.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 109.2ms
# Speed: 0.0ms preprocess, 109.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 97.4ms
# Speed: 2.0ms preprocess, 97.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 94.0ms
# Speed: 2.8ms preprocess, 94.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 98.9ms
# Speed: 1.6ms preprocess, 98.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 94.2ms
# Speed: 2.4ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 105.4ms
# Speed: 2.7ms preprocess, 105.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 92.4ms
# Speed: 3.0ms preprocess, 92.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 98.2ms
# Speed: 1.9ms preprocess, 98.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 97.2ms
# Speed: 2.0ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 98.2ms
# Speed: 2.0ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 92.4ms
# Speed: 2.3ms preprocess, 92.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 102.3ms
# Speed: 3.0ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 107.1ms
# Speed: 2.0ms preprocess, 107.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 103.5ms
# Speed: 2.0ms preprocess, 103.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 99.6ms
# Speed: 0.0ms preprocess, 99.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 111.0ms
# Speed: 0.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 109.5ms
# Speed: 0.0ms preprocess, 109.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 105.3ms
# Speed: 3.0ms preprocess, 105.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 104.3ms
# Speed: 3.0ms preprocess, 104.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 100.8ms
# Speed: 2.8ms preprocess, 100.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 111.1ms
# Speed: 0.9ms preprocess, 111.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 104.3ms
# Speed: 2.2ms preprocess, 104.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 101.0ms
# Speed: 2.6ms preprocess, 101.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 108.3ms
# Speed: 2.0ms preprocess, 108.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 108.7ms
# Speed: 3.2ms preprocess, 108.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 100.5ms
# Speed: 2.5ms preprocess, 100.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 216.8ms
# Speed: 2.0ms preprocess, 216.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 155.5ms
# Speed: 1.1ms preprocess, 155.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 232.4ms
# Speed: 2.8ms preprocess, 232.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 158.3ms
# Speed: 2.3ms preprocess, 158.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 99.1ms
# Speed: 2.0ms preprocess, 99.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 102.2ms
# Speed: 2.4ms preprocess, 102.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 106.7ms
# Speed: 1.9ms preprocess, 106.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 98.5ms
# Speed: 2.6ms preprocess, 98.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 94.3ms
# Speed: 2.3ms preprocess, 94.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 165.8ms
# Speed: 0.0ms preprocess, 165.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 102.5ms
# Speed: 2.8ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 105.0ms
# Speed: 0.7ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 91.7ms
# Speed: 1.1ms preprocess, 91.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 99.2ms
# Speed: 1.2ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 83.5ms
# Speed: 1.2ms preprocess, 83.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 95.6ms
# Speed: 0.0ms preprocess, 95.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 91.3ms
# Speed: 1.9ms preprocess, 91.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 88.9ms
# Speed: 0.7ms preprocess, 88.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 84.0ms
# Speed: 3.0ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 79.3ms
# Speed: 0.0ms preprocess, 79.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 75.2ms
# Speed: 0.0ms preprocess, 75.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 63.7ms
# Speed: 0.0ms preprocess, 63.7ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 105.8ms
# Speed: 3.6ms preprocess, 105.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 94.6ms
# Speed: 0.0ms preprocess, 94.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 84.8ms
# Speed: 0.8ms preprocess, 84.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 88.1ms
# Speed: 2.2ms preprocess, 88.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 75.4ms
# Speed: 0.0ms preprocess, 75.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 72.3ms
# Speed: 0.7ms preprocess, 72.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 65.0ms
# Speed: 0.7ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 61.7ms
# Speed: 1.7ms preprocess, 61.7ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 73.0ms
# Speed: 0.6ms preprocess, 73.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 74.0ms
# Speed: 0.0ms preprocess, 74.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 61.2ms
# Speed: 2.7ms preprocess, 61.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 62.7ms
# Speed: 0.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 64.7ms
# Speed: 0.0ms preprocess, 64.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 87.9ms
# Speed: 3.0ms preprocess, 87.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 85.1ms
# Speed: 1.8ms preprocess, 85.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 78.8ms
# Speed: 2.2ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 82.6ms
# Speed: 1.5ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 76.6ms
# Speed: 2.1ms preprocess, 76.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 69.6ms
# Speed: 1.8ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 71.9ms
# Speed: 1.7ms preprocess, 71.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 86.2ms
# Speed: 1.9ms preprocess, 86.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 79.3ms
# Speed: 0.0ms preprocess, 79.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 77.8ms
# Speed: 0.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 69.5ms
# Speed: 0.7ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 61.4ms
# Speed: 2.2ms preprocess, 61.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 63.5ms
# Speed: 0.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 81.6ms
# Speed: 2.4ms preprocess, 81.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 73.2ms
# Speed: 2.0ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 76.0ms
# Speed: 0.0ms preprocess, 76.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 73.2ms
# Speed: 2.0ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 91.0ms
# Speed: 2.3ms preprocess, 91.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 95.6ms
# Speed: 3.3ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 69.4ms
# Speed: 0.7ms preprocess, 69.4ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 70.6ms
# Speed: 1.8ms preprocess, 70.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 69.8ms
# Speed: 1.4ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 80.8ms
# Speed: 0.0ms preprocess, 80.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 60.6ms
# Speed: 2.1ms preprocess, 60.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 63.4ms
# Speed: 0.0ms preprocess, 63.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 63.6ms
# Speed: 0.0ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 70.4ms
# Speed: 1.5ms preprocess, 70.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 65.7ms
# Speed: 2.0ms preprocess, 65.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 67.9ms
# Speed: 2.6ms preprocess, 67.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 90.0ms
# Speed: 0.0ms preprocess, 90.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 74.4ms
# Speed: 1.4ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 73.0ms
# Speed: 0.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 65.9ms
# Speed: 1.9ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 71.6ms
# Speed: 1.1ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 70.7ms
# Speed: 2.0ms preprocess, 70.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 72.2ms
# Speed: 2.0ms preprocess, 72.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 89.8ms
# Speed: 1.5ms preprocess, 89.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 66.5ms
# Speed: 1.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 69.6ms
# Speed: 1.0ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 74.7ms
# Speed: 0.0ms preprocess, 74.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 61.9ms
# Speed: 1.9ms preprocess, 61.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 63.8ms
# Speed: 2.4ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 74.1ms
# Speed: 1.7ms preprocess, 74.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 90.2ms
# Speed: 0.0ms preprocess, 90.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Video processing completed. Output saved to: vehicle_count_output.mp4
#
# Vehicle Detection Results per Gate:
# Gate 1: BUS 1, CAR 0
# Gate 2: BUS 1, CAR 0
# Gate 3: BUS 0, CAR 1
# Gate 4: BUS 0, CAR 2
# Gate 5: BUS 0, CAR 0
# Gate 6: BUS 0, CAR 0
# Gate 7: BUS 1, CAR 6
# Gate 8: BUS 0, CAR 0
#
# Total:
# BUS = 3, CAR = 9, TOTAL = 12
